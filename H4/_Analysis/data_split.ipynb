# %%
# Post Data
import pandas as pd
import numpy as np
import sqlite3
import pickle
import math
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm

# Import Dataset
conn = sqlite3.connect('/data1/StackOverflow/stackexchange-to-sqlite/stack.db')
query = '''
SELECT id, post_type, creation_date, owner_user_id, tags, body
FROM posts
WHERE creation_date > '2021-09-01'
AND creation_date < '2023-09-01';
'''
df = pd.read_sql_query(query, conn)
conn.close()

# %%
# Load user data with user_type information
user_df = pd.read_csv("split_power_casual.csv")
user_df
# Out:
#          owner_user_id  total_counts  user_type
# 0                  100      2.000000  intensive
# 1             10000015      1.000000     casual
# 2             10000035      1.000000     casual
# 3             10000042      1.000000     casual
# 4             10000051      2.333333  intensive
# ...                ...           ...        ...
# 1564962        9999918      1.000000     casual
# 1564963        9999935      4.000000  intensive
# 1564964        9999957      1.000000     casual
# 1564965        9999964      1.000000     casual
# 1564966        9999993      2.400000  intensive
#
# [1564967 rows x 3 columns]

# %%
# Preprocess
df = df.dropna(subset=['owner_user_id'])
df['owner_user_id'] = df['owner_user_id'].astype(int).astype(str)
df['creation_date'] = pd.to_datetime(df['creation_date'])
df['year_month_day'] = df['creation_date'].dt.to_period('D')
df['year_month_day'] = df['year_month_day'].astype(str)

# %%
df
# Out:
#                id post_type           creation_date owner_user_id  \
# 0        69006420    answer 2021-09-01 00:00:18.070       7332046
# 1        69006421    answer 2021-09-01 00:00:28.823      14471093
# 2        69006422    answer 2021-09-01 00:00:35.537        523612
# 3        69006423  question 2021-09-01 00:00:35.237      14087917
# 4        69006426  question 2021-09-01 00:00:55.583      13091928
# ...           ...       ...                     ...           ...
# 5844592  77019853    answer 2023-08-31 23:56:47.647       5103949
# 5844593  77019854  question 2023-08-31 23:57:28.633       2532775
# 5844594  77019855    answer 2023-08-31 23:57:36.797      16844882
# 5844595  77019856  question 2023-08-31 23:58:56.693       2604570
# 5844596  77019857    answer 2023-08-31 23:59:11.283      13058846
#
#                                                       tags  \
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3        ["node.js", "reactjs", "express", "axios", "re...
# 4                                           ["r", "shiny"]
# ...                                                    ...
# 5844592                                               None
# 5844593  ["angular", "typescript", "progressive-web-app...
# 5844594                                               None
# 5844595                                        ["next.js"]
# 5844596                                               None
#
#                                                       body year_month_day
# 0        <p>The short approach, remove python3.9 from y...     2021-09-01
# 1        <p>open the terminal, run as administrator.</p...     2021-09-01
# 2        <p>Conceptually, <code>Base</code> has no reas...     2021-09-01
# 3        <p>Using interceptors for the first time to re...     2021-09-01
# 4        <p>The APP below uses <code>navbarPage</code>,...     2021-09-01
# ...                                                    ...            ...
# 5844592  <p>I had the same error, I fixed it by followi...     2023-08-31
# 5844593  <p>I utilized the guidelines presented in <a h...     2023-08-31
# 5844594  <p>In your Razor component, you can inject the...     2023-08-31
# 5844595  <p>I have the following structure, i am using ...     2023-08-31
# 5844596  <p>@jwnimmer-tri is working toward a SymPy fea...     2023-08-31
#
# [5790177 rows x 7 columns]

# %%
user_df['owner_user_id'] = user_df['owner_user_id'].astype(str)

# %%
df_merge = pd.merge(df, user_df[['owner_user_id', 'user_type']], on = 'owner_user_id', how = 'left')
df_merge
# Out:
#                id post_type           creation_date owner_user_id  \
# 0        69006420    answer 2021-09-01 00:00:18.070       7332046
# 1        69006421    answer 2021-09-01 00:00:28.823      14471093
# 2        69006422    answer 2021-09-01 00:00:35.537        523612
# 3        69006423  question 2021-09-01 00:00:35.237      14087917
# 4        69006426  question 2021-09-01 00:00:55.583      13091928
# ...           ...       ...                     ...           ...
# 5790172  77019853    answer 2023-08-31 23:56:47.647       5103949
# 5790173  77019854  question 2023-08-31 23:57:28.633       2532775
# 5790174  77019855    answer 2023-08-31 23:57:36.797      16844882
# 5790175  77019856  question 2023-08-31 23:58:56.693       2604570
# 5790176  77019857    answer 2023-08-31 23:59:11.283      13058846
#
#                                                       tags  \
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3        ["node.js", "reactjs", "express", "axios", "re...
# 4                                           ["r", "shiny"]
# ...                                                    ...
# 5790172                                               None
# 5790173  ["angular", "typescript", "progressive-web-app...
# 5790174                                               None
# 5790175                                        ["next.js"]
# 5790176                                               None
#
#                                                       body year_month_day  \
# 0        <p>The short approach, remove python3.9 from y...     2021-09-01
# 1        <p>open the terminal, run as administrator.</p...     2021-09-01
# 2        <p>Conceptually, <code>Base</code> has no reas...     2021-09-01
# 3        <p>Using interceptors for the first time to re...     2021-09-01
# 4        <p>The APP below uses <code>navbarPage</code>,...     2021-09-01
# ...                                                    ...            ...
# 5790172  <p>I had the same error, I fixed it by followi...     2023-08-31
# 5790173  <p>I utilized the guidelines presented in <a h...     2023-08-31
# 5790174  <p>In your Razor component, you can inject the...     2023-08-31
# 5790175  <p>I have the following structure, i am using ...     2023-08-31
# 5790176  <p>@jwnimmer-tri is working toward a SymPy fea...     2023-08-31
#
#          user_type
# 0           casual
# 1           casual
# 2              top
# 3           casual
# 4        intensive
# ...            ...
# 5790172     casual
# 5790173     casual
# 5790174  intensive
# 5790175     casual
# 5790176  intensive
#
# [5790177 rows x 8 columns]

# %%
df_casual = df_merge[df_merge['user_type'] == 'casual']
df_intensive = df_merge[df_merge['user_type'] == 'intensive']
df_top = df_merge[df_merge['user_type'] == 'top']

# %%
questions = df_top[df_top['post_type'] == 'question']
questions
# Out:
#                id post_type           creation_date owner_user_id  \
# 11       69006437  question 2021-09-01 00:03:18.750       2745485
# 76       69006520  question 2021-09-01 00:19:28.923       7360568
# 104      69006556  question 2021-09-01 00:28:08.433      16800531
# 153      69006622  question 2021-09-01 00:42:05.683       7778016
# 404      69006970  question 2021-09-01 01:52:25.597      11267888
# ...           ...       ...                     ...           ...
# 5789303  77018882  question 2023-08-31 19:53:55.183      12547996
# 5789463  77019067  question 2023-08-31 20:24:58.437      22480098
# 5789566  77019177  question 2023-08-31 20:45:22.110      15389244
# 5789638  77019255  question 2023-08-31 21:04:27.977       9998081
# 5789680  77019303  question 2023-08-31 21:12:42.550      22480269
#
#                                                       tags  \
# 11             ["firebase", "nuxt.js", "firebase-hosting"]
# 76                                  ["slack", "slack-api"]
# 104                            ["html", "css", "css-grid"]
# 153                             ["python-3.x", "selenium"]
# 404                                 ["javascript", "cart"]
# ...                                                    ...
# 5789303                                              ["r"]
# 5789463                                            ["c++"]
# 5789566                                     ["r", "dplyr"]
# 5789638  ["php", "wordpress", "woocommerce", "discount"...
# 5789680                               ["c#", ".net", "io"]
#
#                                                       body year_month_day  \
# 11       <p>As you know, all firebase hosting is provid...     2021-09-01
# 76       <p>According to <a href="https://api.slack.com...     2021-09-01
# 104      <p>I am attempting to use CSS grid (orderForm....     2021-09-01
# 153      <p>I have few links with URLs and text inside ...     2021-09-01
# 404      <p>I am trying to have a discount applied to t...     2021-09-01
# ...                                                    ...            ...
# 5789303  <p>Based on the data below, when I bring in a ...     2023-08-31
# 5789463  <p>I cant put <code>cin&gt;&gt;x</code> in the...     2023-08-31
# 5789566  <p>I have data in R that looks like this:</p>\...     2023-08-31
# 5789638  <p>I am adding a WooCommerce cart fee like so ...     2023-08-31
# 5789680  <p>so the code below is checking a file exists...     2023-08-31
#
#         user_type
# 11            top
# 76            top
# 104           top
# 153           top
# 404           top
# ...           ...
# 5789303       top
# 5789463       top
# 5789566       top
# 5789638       top
# 5789680       top
#
# [30517 rows x 8 columns]

# %%
df_q = questions.groupby('year_month_day').size().reset_index(name = 'q')
df_q
# Out:
#     year_month_day   q
# 0       2021-09-01  85
# 1       2021-09-02  77
# 2       2021-09-03  60
# 3       2021-09-04  43
# 4       2021-09-05  45
# ..             ...  ..
# 725     2023-08-27  13
# 726     2023-08-28  35
# 727     2023-08-29  31
# 728     2023-08-30  45
# 729     2023-08-31  37
#
# [730 rows x 2 columns]

# %%
year_month_day = questions.year_month_day.unique()
year_month_day
# Out:
# array(['2021-09-01', '2021-09-02', '2021-09-03', '2021-09-04',
#        '2021-09-05', '2021-09-06', '2021-09-07', '2021-09-08',
#        '2021-09-09', '2021-09-10', '2021-09-11', '2021-09-12',
#        '2021-09-13', '2021-09-14', '2021-09-15', '2021-09-16',
#        '2021-09-17', '2021-09-18', '2021-09-19', '2021-09-20',
#        '2021-09-21', '2021-09-22', '2021-09-23', '2021-09-24',
#        '2021-09-25', '2021-09-26', '2021-09-27', '2021-09-28',
#        '2021-09-29', '2021-09-30', '2021-10-01', '2021-10-02',
#        '2021-10-03', '2021-10-04', '2021-10-05', '2021-10-06',
#        '2021-10-07', '2021-10-08', '2021-10-09', '2021-10-10',
#        '2021-10-11', '2021-10-12', '2021-10-13', '2021-10-14',
#        '2021-10-15', '2021-10-16', '2021-10-17', '2021-10-18',
#        '2021-10-19', '2021-10-20', '2021-10-21', '2021-10-22',
#        '2021-10-23', '2021-10-24', '2021-10-25', '2021-10-26',
#        '2021-10-27', '2021-10-28', '2021-10-29', '2021-10-30',
#        '2021-10-31', '2021-11-01', '2021-11-02', '2021-11-03',
#        '2021-11-04', '2021-11-05', '2021-11-06', '2021-11-07',
#        '2021-11-08', '2021-11-09', '2021-11-10', '2021-11-11',
#        '2021-11-12', '2021-11-13', '2021-11-14', '2021-11-15',
#        '2021-11-16', '2021-11-17', '2021-11-18', '2021-11-19',
#        '2021-11-20', '2021-11-21', '2021-11-22', '2021-11-23',
#        '2021-11-24', '2021-11-25', '2021-11-26', '2021-11-27',
#        '2021-11-28', '2021-11-29', '2021-11-30', '2021-12-01',
#        '2021-12-02', '2021-12-03', '2021-12-04', '2021-12-05',
#        '2021-12-06', '2021-12-07', '2021-12-08', '2021-12-09',
#        '2021-12-10', '2021-12-11', '2021-12-12', '2021-12-13',
#        '2021-12-14', '2021-12-15', '2021-12-16', '2021-12-17',
#        '2021-12-18', '2021-12-19', '2021-12-20', '2021-12-21',
#        '2021-12-22', '2021-12-23', '2021-12-24', '2021-12-25',
#        '2021-12-26', '2021-12-27', '2021-12-28', '2021-12-29',
#        '2021-12-30', '2021-12-31', '2022-01-01', '2022-01-02',
#        '2022-01-03', '2022-01-04', '2022-01-05', '2022-01-06',
#        '2022-01-07', '2022-01-08', '2022-01-09', '2022-01-10',
#        '2022-01-11', '2022-01-12', '2022-01-13', '2022-01-14',
#        '2022-01-15', '2022-01-16', '2022-01-17', '2022-01-18',
#        '2022-01-19', '2022-01-20', '2022-01-21', '2022-01-22',
#        '2022-01-23', '2022-01-24', '2022-01-25', '2022-01-26',
#        '2022-01-27', '2022-01-28', '2022-01-29', '2022-01-30',
#        '2022-01-31', '2022-02-01', '2022-02-02', '2022-02-03',
#        '2022-02-04', '2022-02-05', '2022-02-06', '2022-02-07',
#        '2022-02-08', '2022-02-09', '2022-02-10', '2022-02-11',
#        '2022-02-12', '2022-02-13', '2022-02-14', '2022-02-15',
#        '2022-02-16', '2022-02-17', '2022-02-18', '2022-02-19',
#        '2022-02-20', '2022-02-21', '2022-02-22', '2022-02-23',
#        '2022-02-24', '2022-02-25', '2022-02-26', '2022-02-27',
#        '2022-02-28', '2022-03-01', '2022-03-02', '2022-03-03',
#        '2022-03-04', '2022-03-05', '2022-03-06', '2022-03-07',
#        '2022-03-08', '2022-03-09', '2022-03-10', '2022-03-11',
#        '2022-03-12', '2022-03-13', '2022-03-14', '2022-03-15',
#        '2022-03-16', '2022-03-17', '2022-03-18', '2022-03-19',
#        '2022-03-20', '2022-03-21', '2022-03-22', '2022-03-23',
#        '2022-03-24', '2022-03-25', '2022-03-26', '2022-03-27',
#        '2022-03-28', '2022-03-29', '2022-03-30', '2022-03-31',
#        '2022-04-01', '2022-04-02', '2022-04-03', '2022-04-04',
#        '2022-04-05', '2022-04-06', '2022-04-07', '2022-04-08',
#        '2022-04-09', '2022-04-10', '2022-04-11', '2022-04-12',
#        '2022-04-13', '2022-04-14', '2022-04-15', '2022-04-16',
#        '2022-04-17', '2022-04-18', '2022-04-19', '2022-04-20',
#        '2022-04-21', '2022-04-22', '2022-04-23', '2022-04-24',
#        '2022-04-25', '2022-04-26', '2022-04-27', '2022-04-28',
#        '2022-04-29', '2022-04-30', '2022-05-01', '2022-05-02',
#        '2022-05-03', '2022-05-04', '2022-05-05', '2022-05-06',
#        '2022-05-07', '2022-05-08', '2022-05-09', '2022-05-10',
#        '2022-05-11', '2022-05-12', '2022-05-13', '2022-05-14',
#        '2022-05-15', '2022-05-16', '2022-05-17', '2022-05-18',
#        '2022-05-19', '2022-05-20', '2022-05-21', '2022-05-22',
#        '2022-05-23', '2022-05-24', '2022-05-25', '2022-05-26',
#        '2022-05-27', '2022-05-28', '2022-05-29', '2022-05-30',
#        '2022-05-31', '2022-06-01', '2022-06-02', '2022-06-03',
#        '2022-06-04', '2022-06-05', '2022-06-06', '2022-06-07',
#        '2022-06-08', '2022-06-09', '2022-06-10', '2022-06-11',
#        '2022-06-12', '2022-06-13', '2022-06-14', '2022-06-15',
#        '2022-06-16', '2022-06-17', '2022-06-18', '2022-06-19',
#        '2022-06-20', '2022-06-21', '2022-06-22', '2022-06-23',
#        '2022-06-24', '2022-06-25', '2022-06-26', '2022-06-27',
#        '2022-06-28', '2022-06-29', '2022-06-30', '2022-07-01',
#        '2022-07-02', '2022-07-03', '2022-07-04', '2022-07-05',
#        '2022-07-06', '2022-07-07', '2022-07-08', '2022-07-09',
#        '2022-07-10', '2022-07-11', '2022-07-12', '2022-07-13',
#        '2022-07-14', '2022-07-15', '2022-07-16', '2022-07-17',
#        '2022-07-18', '2022-07-19', '2022-07-20', '2022-07-21',
#        '2022-07-22', '2022-07-23', '2022-07-24', '2022-07-25',
#        '2022-07-26', '2022-07-27', '2022-07-28', '2022-07-29',
#        '2022-07-30', '2022-07-31', '2022-08-01', '2022-08-02',
#        '2022-08-03', '2022-08-04', '2022-08-05', '2022-08-06',
#        '2022-08-07', '2022-08-08', '2022-08-09', '2022-08-10',
#        '2022-08-11', '2022-08-12', '2022-08-13', '2022-08-14',
#        '2022-08-15', '2022-08-16', '2022-08-17', '2022-08-18',
#        '2022-08-19', '2022-08-20', '2022-08-21', '2022-08-22',
#        '2022-08-23', '2022-08-24', '2022-08-25', '2022-08-26',
#        '2022-08-27', '2022-08-28', '2022-08-29', '2022-08-30',
#        '2022-08-31', '2022-09-01', '2022-09-02', '2022-09-03',
#        '2022-09-04', '2022-09-05', '2022-09-06', '2022-09-07',
#        '2022-09-08', '2022-09-09', '2022-09-10', '2022-09-11',
#        '2022-09-12', '2022-09-13', '2022-09-14', '2022-09-15',
#        '2022-09-16', '2022-09-17', '2022-09-18', '2022-09-19',
#        '2022-09-20', '2022-09-21', '2022-09-22', '2022-09-23',
#        '2022-09-24', '2022-09-25', '2022-09-26', '2022-09-27',
#        '2022-09-28', '2022-09-29', '2022-09-30', '2022-10-01',
#        '2022-10-02', '2022-10-03', '2022-10-04', '2022-10-05',
#        '2022-10-06', '2022-10-07', '2022-10-08', '2022-10-09',
#        '2022-10-10', '2022-10-11', '2022-10-12', '2022-10-13',
#        '2022-10-14', '2022-10-15', '2022-10-16', '2022-10-17',
#        '2022-10-18', '2022-10-19', '2022-10-20', '2022-10-21',
#        '2022-10-22', '2022-10-23', '2022-10-24', '2022-10-25',
#        '2022-10-26', '2022-10-27', '2022-10-28', '2022-10-29',
#        '2022-10-30', '2022-10-31', '2022-11-01', '2022-11-02',
#        '2022-11-03', '2022-11-04', '2022-11-05', '2022-11-06',
#        '2022-11-07', '2022-11-08', '2022-11-09', '2022-11-10',
#        '2022-11-11', '2022-11-12', '2022-11-13', '2022-11-14',
#        '2022-11-15', '2022-11-16', '2022-11-17', '2022-11-18',
#        '2022-11-19', '2022-11-20', '2022-11-21', '2022-11-22',
#        '2022-11-23', '2022-11-24', '2022-11-25', '2022-11-26',
#        '2022-11-27', '2022-11-28', '2022-11-29', '2022-11-30',
#        '2022-12-01', '2022-12-02', '2022-12-03', '2022-12-04',
#        '2022-12-05', '2022-12-06', '2022-12-07', '2022-12-08',
#        '2022-12-09', '2022-12-10', '2022-12-11', '2022-12-12',
#        '2022-12-13', '2022-12-14', '2022-12-15', '2022-12-16',
#        '2022-12-17', '2022-12-18', '2022-12-19', '2022-12-20',
#        '2022-12-21', '2022-12-22', '2022-12-23', '2022-12-24',
#        '2022-12-25', '2022-12-26', '2022-12-27', '2022-12-28',
#        '2022-12-29', '2022-12-30', '2022-12-31', '2023-01-01',
#        '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05',
#        '2023-01-06', '2023-01-07', '2023-01-08', '2023-01-09',
#        '2023-01-10', '2023-01-11', '2023-01-12', '2023-01-13',
#        '2023-01-14', '2023-01-15', '2023-01-16', '2023-01-17',
#        '2023-01-18', '2023-01-19', '2023-01-20', '2023-01-21',
#        '2023-01-22', '2023-01-23', '2023-01-24', '2023-01-25',
#        '2023-01-26', '2023-01-27', '2023-01-28', '2023-01-29',
#        '2023-01-30', '2023-01-31', '2023-02-01', '2023-02-02',
#        '2023-02-03', '2023-02-04', '2023-02-05', '2023-02-06',
#        '2023-02-07', '2023-02-08', '2023-02-09', '2023-02-10',
#        '2023-02-11', '2023-02-12', '2023-02-13', '2023-02-14',
#        '2023-02-15', '2023-02-16', '2023-02-17', '2023-02-18',
#        '2023-02-19', '2023-02-20', '2023-02-21', '2023-02-22',
#        '2023-02-23', '2023-02-24', '2023-02-25', '2023-02-26',
#        '2023-02-27', '2023-02-28', '2023-03-01', '2023-03-02',
#        '2023-03-03', '2023-03-04', '2023-03-05', '2023-03-06',
#        '2023-03-07', '2023-03-08', '2023-03-09', '2023-03-10',
#        '2023-03-11', '2023-03-12', '2023-03-13', '2023-03-14',
#        '2023-03-15', '2023-03-16', '2023-03-17', '2023-03-18',
#        '2023-03-19', '2023-03-20', '2023-03-21', '2023-03-22',
#        '2023-03-23', '2023-03-24', '2023-03-25', '2023-03-26',
#        '2023-03-27', '2023-03-28', '2023-03-29', '2023-03-30',
#        '2023-03-31', '2023-04-01', '2023-04-02', '2023-04-03',
#        '2023-04-04', '2023-04-05', '2023-04-06', '2023-04-07',
#        '2023-04-08', '2023-04-09', '2023-04-10', '2023-04-11',
#        '2023-04-12', '2023-04-13', '2023-04-14', '2023-04-15',
#        '2023-04-16', '2023-04-17', '2023-04-18', '2023-04-19',
#        '2023-04-20', '2023-04-21', '2023-04-22', '2023-04-23',
#        '2023-04-24', '2023-04-25', '2023-04-26', '2023-04-27',
#        '2023-04-28', '2023-04-29', '2023-04-30', '2023-05-01',
#        '2023-05-02', '2023-05-03', '2023-05-04', '2023-05-05',
#        '2023-05-06', '2023-05-07', '2023-05-08', '2023-05-09',
#        '2023-05-10', '2023-05-11', '2023-05-12', '2023-05-13',
#        '2023-05-14', '2023-05-15', '2023-05-16', '2023-05-17',
#        '2023-05-18', '2023-05-19', '2023-05-20', '2023-05-21',
#        '2023-05-22', '2023-05-23', '2023-05-24', '2023-05-25',
#        '2023-05-26', '2023-05-27', '2023-05-28', '2023-05-29',
#        '2023-05-30', '2023-05-31', '2023-06-01', '2023-06-02',
#        '2023-06-03', '2023-06-04', '2023-06-05', '2023-06-06',
#        '2023-06-07', '2023-06-08', '2023-06-09', '2023-06-10',
#        '2023-06-11', '2023-06-12', '2023-06-13', '2023-06-14',
#        '2023-06-15', '2023-06-16', '2023-06-17', '2023-06-18',
#        '2023-06-19', '2023-06-20', '2023-06-21', '2023-06-22',
#        '2023-06-23', '2023-06-24', '2023-06-25', '2023-06-26',
#        '2023-06-27', '2023-06-28', '2023-06-29', '2023-06-30',
#        '2023-07-01', '2023-07-02', '2023-07-03', '2023-07-04',
#        '2023-07-05', '2023-07-06', '2023-07-07', '2023-07-08',
#        '2023-07-09', '2023-07-10', '2023-07-11', '2023-07-12',
#        '2023-07-13', '2023-07-14', '2023-07-15', '2023-07-16',
#        '2023-07-17', '2023-07-18', '2023-07-19', '2023-07-20',
#        '2023-07-21', '2023-07-22', '2023-07-23', '2023-07-24',
#        '2023-07-25', '2023-07-26', '2023-07-27', '2023-07-28',
#        '2023-07-29', '2023-07-30', '2023-07-31', '2023-08-01',
#        '2023-08-02', '2023-08-03', '2023-08-04', '2023-08-05',
#        '2023-08-06', '2023-08-07', '2023-08-08', '2023-08-09',
#        '2023-08-10', '2023-08-11', '2023-08-12', '2023-08-13',
#        '2023-08-14', '2023-08-15', '2023-08-16', '2023-08-17',
#        '2023-08-18', '2023-08-19', '2023-08-20', '2023-08-21',
#        '2023-08-22', '2023-08-23', '2023-08-24', '2023-08-25',
#        '2023-08-26', '2023-08-27', '2023-08-28', '2023-08-29',
#        '2023-08-30', '2023-08-31'], dtype=object)

# %%
all_keys = tag_freq(questions)
all_keys = pd.DataFrame(all_keys, index = ['tag']).transpose().reset_index()
all_keys
# Out:
#                        index  tag
# 0                   firebase  278
# 1                  nuxtDOTjs   33
# 2            firebasehosting    3
# 3                      slack    4
# 4                   slackapi    2
# ...                      ...  ...
# 8821  visualstudioextensions    1
# 8822                 nothrow    1
# 8823                   mpesa    1
# 8824           firebird1DOT5    1
# 8825                discount    1
#
# [8826 rows x 2 columns]

# %%
for i in range(len(year_month_day)):
    target_data = questions[questions['year_month_day'] == year_month_day[i]]
    tags = tag_freq(target_data)
    tagCount = pd.DataFrame(tags, index = ['tag']).transpose().reset_index()
    tagShare = []
    for j in range(len(tagCount)):
        tagShare.append((tagCount['tag'][j] / tagCount['tag'].sum())*100)
    tagCount['tagShare'] = tagShare
    varName = year_month_day[i].replace('-', '_')
    tagCount = tagCount.rename(columns = {'tag':f'tag_{varName}','tagShare':f'tagShare_{varName}'})
    # merge here.
    all_keys = pd.merge(all_keys, tagCount, on = 'index', how = 'left')

# %%
all_keys
# Out:
#                        index  tag  tag_2021_09_01  tagShare_2021_09_01  \
# 0                   firebase  278             1.0             0.390625
# 1                  nuxtDOTjs   33             1.0             0.390625
# 2            firebasehosting    3             1.0             0.390625
# 3                      slack    4             1.0             0.390625
# 4                   slackapi    2             1.0             0.390625
# ...                      ...  ...             ...                  ...
# 8821  visualstudioextensions    1             NaN                  NaN
# 8822                 nothrow    1             NaN                  NaN
# 8823                   mpesa    1             NaN                  NaN
# 8824           firebird1DOT5    1             NaN                  NaN
# 8825                discount    1             NaN                  NaN
#
#       tag_2021_09_02  tagShare_2021_09_02  tag_2021_09_03  \
# 0                2.0             0.826446             1.0
# 1                NaN                  NaN             NaN
# 2                NaN                  NaN             NaN
# 3                NaN                  NaN             NaN
# 4                NaN                  NaN             NaN
# ...              ...                  ...             ...
# 8821             NaN                  NaN             NaN
# 8822             NaN                  NaN             NaN
# 8823             NaN                  NaN             NaN
# 8824             NaN                  NaN             NaN
# 8825             NaN                  NaN             NaN
#
#       tagShare_2021_09_03  tag_2021_09_04  tagShare_2021_09_04  ...  \
# 0                0.534759             NaN                  NaN  ...
# 1                     NaN             NaN                  NaN  ...
# 2                     NaN             NaN                  NaN  ...
# 3                     NaN             NaN                  NaN  ...
# 4                     NaN             NaN                  NaN  ...
# ...                   ...             ...                  ...  ...
# 8821                  NaN             NaN                  NaN  ...
# 8822                  NaN             NaN                  NaN  ...
# 8823                  NaN             NaN                  NaN  ...
# 8824                  NaN             NaN                  NaN  ...
# 8825                  NaN             NaN                  NaN  ...
#
#       tag_2023_08_27  tagShare_2023_08_27  tag_2023_08_28  \
# 0                1.0             2.222222             NaN
# 1                NaN                  NaN             NaN
# 2                NaN                  NaN             NaN
# 3                NaN                  NaN             NaN
# 4                NaN                  NaN             NaN
# ...              ...                  ...             ...
# 8821             NaN                  NaN             NaN
# 8822             NaN                  NaN             NaN
# 8823             NaN                  NaN             NaN
# 8824             NaN                  NaN             NaN
# 8825             NaN                  NaN             NaN
#
#       tagShare_2023_08_28  tag_2023_08_29  tagShare_2023_08_29  \
# 0                     NaN             NaN                  NaN
# 1                     NaN             NaN                  NaN
# 2                     NaN             NaN                  NaN
# 3                     NaN             NaN                  NaN
# 4                     NaN             NaN                  NaN
# ...                   ...             ...                  ...
# 8821                  NaN             NaN                  NaN
# 8822                  NaN             NaN                  NaN
# 8823                  NaN             NaN                  NaN
# 8824                  NaN             NaN                  NaN
# 8825                  NaN             NaN                  NaN
#
#       tag_2023_08_30  tagShare_2023_08_30  tag_2023_08_31  tagShare_2023_08_31
# 0                NaN                  NaN             1.0             0.900901
# 1                NaN                  NaN             NaN                  NaN
# 2                NaN                  NaN             NaN                  NaN
# 3                NaN                  NaN             NaN                  NaN
# 4                NaN                  NaN             NaN                  NaN
# ...              ...                  ...             ...                  ...
# 8821             1.0              0.70922             NaN                  NaN
# 8822             1.0              0.70922             NaN                  NaN
# 8823             NaN                  NaN             1.0             0.900901
# 8824             NaN                  NaN             1.0             0.900901
# 8825             NaN                  NaN             1.0             0.900901
#
# [8826 rows x 1462 columns]

# %%
# Measure score
entropy_Score = []
# Calculate Entropy for each monthly tag share column.
for i in range(3, all_keys.shape[1], 2):
    arr = np.array(all_keys.iloc[:, i])
    arr = arr/100
    arrList = arr.tolist()
    entropy_Score.append(calculate_entropy(arrList))

# %%
len(entropy_Score)
# Out:
# 730

# %%
pg.27 첫번 쨰 스텝이 분해하는 것인데, 분해가 잘 되었다고는 어떻게 알 수 있나용?

# %%
casual = pd.read_csv('df_split_casual.csv')
casual
# Out:
#     year_month_day  T_d  P_t  month     q  a      ln_q  ln_a    entropy  \
# 0       2021-09-01    0    0      9  2652  0  7.883069  -inf   9.672691
# 1       2021-09-02    0    0      9  2675  0  7.891705  -inf   9.617068
# 2       2021-09-03    0    0      9  2338  0  7.757051  -inf   9.672048
# 3       2021-09-04    0    0      9  1313  0  7.180070  -inf   9.194534
# 4       2021-09-05    0    0      9  1343  0  7.202661  -inf   9.141328
# ..             ...  ...  ...    ...   ... ..       ...   ...        ...
# 725     2023-08-27    1    1      8  1308  0  7.176255  -inf   9.447730
# 726     2023-08-28    1    1      8  2266  0  7.725771  -inf   9.962066
# 727     2023-08-29    1    1      8  2418  0  7.790696  -inf  10.001658
# 728     2023-08-30    1    1      8  2532  0  7.836765  -inf  10.039628
# 729     2023-08-31    1    1      8  2506  0  7.826443  -inf  10.005546
#
#      ln_entropy       lsm    ln_lsm
# 0      2.269307  0.085186 -2.462922
# 1      2.263539  0.098764 -2.315024
# 2      2.269240  0.093233 -2.372651
# 3      2.218609  0.109986 -2.207402
# 4      2.212806  0.108032 -2.225332
# ..          ...       ...       ...
# 725    2.245774  0.121113 -2.111031
# 726    2.298784  0.115723 -2.156557
# 727    2.302751  0.104343 -2.260069
# 728    2.306540  0.140746 -1.960796
# 729    2.303140  0.104043 -2.262950
#
# [730 rows x 12 columns]

# %%
intensive = pd.read_csv('df_split_intensive.csv')
intensive
# Out:
#     year_month_day  T_d  P_t  month     q  a      ln_q  ln_a   entropy  \
# 0       2021-09-01    0    0      9  1940  0  7.570443  -inf  8.966081
# 1       2021-09-02    0    0      9  2013  0  7.607381  -inf  8.991894
# 2       2021-09-03    0    0      9  1679  0  7.425954  -inf  9.002499
# 3       2021-09-04    0    0      9  1038  0  6.945051  -inf  8.479622
# 4       2021-09-05    0    0      9   997  0  6.904751  -inf  8.569897
# ..             ...  ...  ...    ...   ... ..       ...   ...       ...
# 725     2023-08-27    1    1      8   555  0  6.318968  -inf  8.699824
# 726     2023-08-28    1    1      8   982  0  6.889591  -inf  9.162927
# 727     2023-08-29    1    1      8  1103  0  7.005789  -inf  9.251995
# 728     2023-08-30    1    1      8  1196  0  7.086738  -inf  9.252655
# 729     2023-08-31    1    1      8  1130  0  7.029973  -inf  9.219159
#
#      ln_entropy       lsm    ln_lsm
# 0      2.193449  0.110529 -2.202481
# 1      2.196324  0.122963 -2.095871
# 2      2.197502  0.116329 -2.151331
# 3      2.137666  0.132860 -2.018461
# 4      2.148256  0.135432 -1.999285
# ..          ...       ...       ...
# 725    2.163303  0.146551 -1.920383
# 726    2.215166  0.142119 -1.951092
# 727    2.224839  0.130770 -2.034318
# 728    2.224911  0.167037 -1.789539
# 729    2.221284  0.127033 -2.063308
#
# [730 rows x 12 columns]

# %%
top = pd.read_csv('df_split_top.csv')
top
# Out:
#     year_month_day  T_d  P_t  month   q  a      ln_q  ln_a   entropy  \
# 0       2021-09-01    0    0      9  85  0  4.442651  -inf  6.969697
# 1       2021-09-02    0    0      9  77  0  4.343805  -inf  6.981069
# 2       2021-09-03    0    0      9  60  0  4.094345  -inf  6.542010
# 3       2021-09-04    0    0      9  43  0  3.761200  -inf  6.250302
# 4       2021-09-05    0    0      9  45  0  3.806662  -inf  6.287710
# ..             ...  ...  ...    ...  .. ..       ...   ...       ...
# 725     2023-08-27    1    1      8  13  0  2.564949  -inf  5.102747
# 726     2023-08-28    1    1      8  35  0  3.555348  -inf  6.231867
# 727     2023-08-29    1    1      8  31  0  3.433987  -inf  5.705714
# 728     2023-08-30    1    1      8  45  0  3.806662  -inf  6.455705
# 729     2023-08-31    1    1      8  37  0  3.610918  -inf  6.236990
#
#      ln_entropy       lsm    ln_lsm
# 0      1.941572  0.160669 -1.828408
# 1      1.943202  0.182673 -1.700059
# 2      1.878244  0.169282 -1.776189
# 3      1.832630  0.183321 -1.696518
# 4      1.838597  0.190067 -1.660378
# ..          ...       ...       ...
# 725    1.629779  0.180791 -1.710412
# 726    1.829676  0.180781 -1.710467
# 727    1.741468  0.163347 -1.811879
# 728    1.864964  0.211216 -1.554874
# 729    1.830498  0.168208 -1.782551
#
# [730 rows x 12 columns]

# %%
intensive[intensive['entropy'] == 0]
# Out:
# Empty DataFrame
# Columns: [year_month_day, T_d, P_t, month, q, a, ln_q, ln_a, entropy, ln_entropy, lsm, ln_lsm]
# Index: []

# %%
intensive.isna().sum()
# Out:
# year_month_day    0
# T_d               0
# P_t               0
# month             0
# q                 0
# a                 0
# ln_q              0
# ln_a              0
# entropy           0
# ln_entropy        0
# lsm               0
# ln_lsm            0
# dtype: int64

# %%
top.isna().sum()
# Out:
# year_month_day    0
# T_d               0
# P_t               0
# month             0
# q                 0
# a                 0
# ln_q              0
# ln_a              0
# entropy           0
# ln_entropy        0
# lsm               0
# ln_lsm            0
# dtype: int64

# %%
casual.describe()
# Out:
# /home/cglee/anaconda3/envs/ahnlab/lib/python3.10/site-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/cglee/anaconda3/envs/ahnlab/lib/python3.10/site-packages/numpy/lib/function_base.py:4655: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
#               T_d         P_t       month            q      a        ln_q  \
# count  730.000000  730.000000  730.000000   730.000000  730.0  730.000000
# mean     0.500000    0.753425    6.526027  2261.423288    0.0    7.679317
# std      0.500343    0.431313    3.450215   630.954132    0.0    0.309726
# min      0.000000    0.000000    1.000000  1009.000000    0.0    6.916715
# 25%      0.000000    1.000000    4.000000  1635.000000    0.0    7.399398
# 50%      0.500000    1.000000    7.000000  2378.000000    0.0    7.774015
# 75%      1.000000    1.000000   10.000000  2666.500000    0.0    7.888522
# max      1.000000    1.000000   12.000000  3701.000000    0.0    8.216358
#
#         ln_a     entropy  ln_entropy         lsm      ln_lsm
# count  730.0  730.000000  730.000000  730.000000  730.000000
# mean    -inf    9.656151    2.267201    0.104483   -2.266637
# std      NaN    0.270293    0.028172    0.013354    0.125144
# min     -inf    8.991220    2.196249    0.065848   -2.720403
# 25%      NaN    9.486660    2.249887    0.095156   -2.352234
# 50%      NaN    9.671182    2.269151    0.102770   -2.275264
# 75%      NaN    9.907074    2.293249    0.112246   -2.187067
# max     -inf   10.101883    2.312722    0.154568   -1.867120

# %%
top.describe()
# Out:
# /home/cglee/anaconda3/envs/ahnlab/lib/python3.10/site-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/cglee/anaconda3/envs/ahnlab/lib/python3.10/site-packages/numpy/lib/function_base.py:4655: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
#               T_d         P_t       month           q      a        ln_q  \
# count  730.000000  730.000000  730.000000  730.000000  730.0  730.000000
# mean     0.500000    0.753425    6.526027   41.804110    0.0    3.642444
# std      0.500343    0.431313    3.450215   16.277725    0.0    0.455714
# min      0.000000    0.000000    1.000000    5.000000    0.0    1.609438
# 25%      0.000000    1.000000    4.000000   29.000000    0.0    3.367296
# 50%      0.500000    1.000000    7.000000   42.000000    0.0    3.737670
# 75%      1.000000    1.000000   10.000000   53.000000    0.0    3.970292
# max      1.000000    1.000000   12.000000   93.000000    0.0    4.532599
#
#         ln_a     entropy  ln_entropy         lsm      ln_lsm
# count  730.0  730.000000  730.000000  730.000000  730.000000
# mean    -inf    6.116709    1.807756    0.171856   -1.763665
# std      NaN    0.476742    0.082540    0.012451    0.071421
# min     -inf    4.000000    1.386294    0.138616   -1.976046
# 25%      NaN    5.899646    1.774892    0.163045   -1.813730
# 50%      NaN    6.201120    1.824730    0.170473   -1.769180
# 75%      NaN    6.438208    1.862250    0.179489   -1.717641
# max     -inf    6.999526    1.945842    0.226038   -1.487052

# %%
intensive.describe()
# Out:
# /home/cglee/anaconda3/envs/ahnlab/lib/python3.10/site-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/cglee/anaconda3/envs/ahnlab/lib/python3.10/site-packages/numpy/lib/function_base.py:4655: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
#               T_d         P_t       month            q      a        ln_q  \
# count  730.000000  730.000000  730.000000   730.000000  730.0  730.000000
# mean     0.500000    0.753425    6.526027  1372.005479    0.0    7.168352
# std      0.500343    0.431313    3.450215   423.105687    0.0    0.349728
# min      0.000000    0.000000    1.000000   497.000000    0.0    6.208590
# 25%      0.000000    1.000000    4.000000  1015.500000    0.0    6.923136
# 50%      0.500000    1.000000    7.000000  1445.000000    0.0    7.275864
# 75%      1.000000    1.000000   10.000000  1760.250000    0.0    7.473211
# max      1.000000    1.000000   12.000000  2072.000000    0.0    7.636270
#
#         ln_a     entropy  ln_entropy         lsm      ln_lsm
# count  730.0  730.000000  730.000000  730.000000  730.000000
# mean    -inf    8.971294    2.193778    0.128957   -2.053776
# std      NaN    0.200708    0.022534    0.013747    0.104246
# min     -inf    8.474723    2.137088    0.091784   -2.388315
# 25%      NaN    8.805100    2.175331    0.119164   -2.127251
# 50%      NaN    9.026382    2.200152    0.126880   -2.064517
# 75%      NaN    9.114223    2.209836    0.136544   -1.991112
# max     -inf    9.314384    2.231560    0.183544   -1.695302
