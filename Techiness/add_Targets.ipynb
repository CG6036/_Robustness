# %% [markdown]
# # Add 3 response(target) variables
# - ln(Number of Comments)
# - ln(Number of Answers per Question)
# - ln(Comment per Post)

# %%
# Import Modules
import pandas as pd
import numpy as np
import sqlite3
import pickle
import math
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm

# Import Dataset
conn = sqlite3.connect('/data1/StackOverflow/stackexchange-to-sqlite/stack.db')
query = '''
SELECT id, creation_date, answers, comments, owner_user_id
FROM questions
WHERE creation_date > '2021-09-01'
AND creation_date < '2023-09-01';
'''
df = pd.read_sql_query(query, conn)
conn.close()

# %%
df
# Out:
#                id            creation_date  answers  comments  owner_user_id
# 0        69006423  2021-09-01 00:00:35.237        1         0     14087917.0
# 1        69006426  2021-09-01 00:00:55.583        1         0     13091928.0
# 2        69006431  2021-09-01 00:01:23.670        1         2      8110267.0
# 3        69006437  2021-09-01 00:03:18.750        1         0      2745485.0
# 4        69006439  2021-09-01 00:03:36.930        1         2     12139975.0
# ...           ...                      ...      ...       ...            ...
# 2715204  77019848  2023-08-31 23:54:30.057        1         2      1006272.0
# 2715205  77019849  2023-08-31 23:55:21.660        0         0     15216800.0
# 2715206  77019852  2023-08-31 23:56:42.653        1         2       433202.0
# 2715207  77019854  2023-08-31 23:57:28.633        0         2      2532775.0
# 2715208  77019856  2023-08-31 23:58:56.693        0         0      2604570.0
#
# [2715209 rows x 5 columns]

# %%
df.describe()
# Out:
#                  id       answers      comments  owner_user_id
# count  2.715209e+06  2.715209e+06  2.715209e+06   2.682920e+06
# mean   7.322387e+07  9.339351e-01  1.844893e+00   1.254379e+07
# std    2.333213e+06  8.636178e-01  2.554058e+00   6.686994e+06
# min    6.900642e+07  0.000000e+00  0.000000e+00   2.900000e+01
# 25%    7.120200e+07  0.000000e+00  0.000000e+00   6.691575e+06
# 50%    7.338874e+07  1.000000e+00  1.000000e+00   1.397384e+07
# 75%    7.525579e+07  1.000000e+00  3.000000e+00   1.826946e+07
# max    7.701986e+07  6.000000e+01  6.200000e+01   2.248065e+07

# %% [markdown]
# ### 1) Number of Comments

# %%
# Load Data (preChatGPT)
with open(file = 'ques_df_pre.pickle', mode = 'rb') as file:
    ques_df = pickle.load(file)

# %%
df_merge = pd.merge(ques_df, df, on = ['id', 'creation_date'], how = 'left')
df_merge
# Out:
#                id            creation_date  \
# 0        69006423  2021-09-01 00:00:35.237
# 1        69006426  2021-09-01 00:00:55.583
# 2        69006431  2021-09-01 00:01:23.670
# 3        69006437  2021-09-01 00:03:18.750
# 4        69006439  2021-09-01 00:03:36.930
# ...           ...                      ...
# 2713807  77019848  2023-08-31 23:54:30.057
# 2713808  77019849  2023-08-31 23:55:21.660
# 2713809  77019852  2023-08-31 23:56:42.653
# 2713810  77019854  2023-08-31 23:57:28.633
# 2713811  77019856  2023-08-31 23:58:56.693
#
#                                                       body  \
# 0        <p>Using interceptors for the first time to re...
# 1        <p>The APP below uses <code>navbarPage</code>,...
# 2        <p>I am developing a java project and every th...
# 3        <p>As you know, all firebase hosting is provid...
# 4        <p>I am trying to split the string as below</p...
# ...                                                    ...
# 2713807  <p>I need help solving a CORS issue.</p>\n<p>I...
# 2713808  <p>I am currently attempting to search a Share...
# 2713809  <p>Similar to <a href="https://stackoverflow.c...
# 2713810  <p>I utilized the guidelines presented in <a h...
# 2713811  <p>I have the following structure, i am using ...
#
#                                                       tags  community  \
# 0        [nodeDOTjs, reactjs, express, axios, refreshto...          0
# 1                                               [r, shiny]         17
# 2        [java, installation, compilation, project, ope...          3
# 3                   [firebase, nuxtDOTjs, firebasehosting]          5
# 4                                        [r, dataDOTtable]         17
# ...                                                    ...        ...
# 2713807  [docker, dockercompose, owaspdependencycheck, ...          7
# 2713808              [microsoftgraphapi, sharepointonline]          1
# 2713809                     [python, numpy, floatingpoint]         17
# 2713810  [angular, typescript, progressivewebapps, ngsw...          0
# 2713811                                        [nextDOTjs]          0
#
#                                                  full_body  \
# 0        Using interceptors for the first time to refre...
# 1        The APP below uses navbarPage, however I will ...
# 2        I am developing a java project and every thing...
# 3        As you know, all firebase hosting is provided ...
# 4        I am trying to split the string as below\nx <-...
# ...                                                    ...
# 2713807  I need help solving a CORS issue.\nI am trying...
# 2713808  I am currently attempting to search a SharePoi...
# 2713809  Similar to Numpy astype rounding to wrong valu...
# 2713810  I utilized the guidelines presented in this ar...
# 2713811  I have the following structure, i am using par...
#
#                                                  code_body  answers  comments  \
# 0                                                                 1         0
# 1        dashboardPage\nnavbarPage\nlibrary(shiny)\nlib...        1         0
# 2                                                                 1         2
# 3        [\n      '@nuxtjs/firebase',\n      {\n       ...        1         0
# 4        x <- data.table(VAROLD=c('DBA','ADB'))\nx[, pa...        1         2
# ...                                                    ...      ...       ...
# 2713807  - API_BASE_URL=http://XXX.XXX.XX.XX:8081\nAcce...        1         2
# 2713808  {\n     "requests": [\n         {\n           ...        0         0
# 2713809  In [2]: import numpy as np\n\n...\n\nIn [49]: ...        1         2
# 2713810  import {BrowserModule} from '@angular/platform...        0         2
# 2713811  folder1\nfolder2\n@folder2/page.tsx\n@folder3/...        0         0
#
#          owner_user_id
# 0           14087917.0
# 1           13091928.0
# 2            8110267.0
# 3            2745485.0
# 4           12139975.0
# ...                ...
# 2713807      1006272.0
# 2713808     15216800.0
# 2713809       433202.0
# 2713810      2532775.0
# 2713811      2604570.0
#
# [2713812 rows x 10 columns]

# %%
#create daily timeseries data
df_merge['year_month_day'] = pd.to_datetime(df_merge['creation_date']).dt.to_period('D') # daily
df_merge['year_month_day'] = df_merge['year_month_day'].astype(str)

# %%
numComments = df_merge.groupby(['year_month_day', 'community'])['comments'].sum().reset_index()
numComments
# Out:
#       year_month_day  community  comments
# 0         2021-09-01          0      2291
# 1         2021-09-01          1       938
# 2         2021-09-01          3       841
# 3         2021-09-01          4      1365
# 4         2021-09-01          5       569
# ...              ...        ...       ...
# 10891     2023-08-31         11        22
# 10892     2023-08-31         13        39
# 10893     2023-08-31         14         1
# 10894     2023-08-31         15         2
# 10895     2023-08-31         17      1222
#
# [10896 rows x 3 columns]

# %% [markdown]
# ### 2) Avg Number of Answers per Question

# %%
# use average
AnsPerQ = df_merge.groupby(['year_month_day', 'community'])['answers'].mean().reset_index(name = 'AnsPerQ')
AnsPerQ
# Out:
#       year_month_day  community   AnsPerQ
# 0         2021-09-01          0  1.164056
# 1         2021-09-01          1  1.032419
# 2         2021-09-01          3  1.010152
# 3         2021-09-01          4  1.141304
# 4         2021-09-01          5  1.190476
# ...              ...        ...       ...
# 10891     2023-08-31         11  0.666667
# 10892     2023-08-31         13  0.413793
# 10893     2023-08-31         14  0.000000
# 10894     2023-08-31         15  0.600000
# 10895     2023-08-31         17  0.582763
#
# [10896 rows x 3 columns]

# %%
AnsPerQ.describe()
# Out:
#           community       AnsPerQ
# count  10896.000000  10896.000000
# mean       8.192823      0.906343
# std        5.015349      0.246640
# min        0.000000      0.000000
# 25%        4.000000      0.755102
# 50%        8.000000      0.921348
# 75%       13.000000      1.050000
# max       17.000000      4.000000

# %% [markdown]
# ### 3) Avg Number of Comments per Question

# %%
ComPerQ = df_merge.groupby(['year_month_day', 'community'])['comments'].mean().reset_index(name = 'CommentsPerQ')
ComPerQ
# Out:
#       year_month_day  community  CommentsPerQ
# 0         2021-09-01          0      1.888706
# 1         2021-09-01          1      2.339152
# 2         2021-09-01          3      2.134518
# 3         2021-09-01          4      3.709239
# 4         2021-09-01          5      1.505291
# ...              ...        ...           ...
# 10891     2023-08-31         11      1.222222
# 10892     2023-08-31         13      1.344828
# 10893     2023-08-31         14      0.125000
# 10894     2023-08-31         15      0.400000
# 10895     2023-08-31         17      1.671683
#
# [10896 rows x 3 columns]

# %%
ComPerQ.describe()
# Out:
#           community  CommentsPerQ
# count  10896.000000  10896.000000
# mean       8.192823      1.630200
# std        5.015349      0.761821
# min        0.000000      0.000000
# 25%        4.000000      1.200718
# 50%        8.000000      1.645863
# 75%       13.000000      2.034106
# max       17.000000     11.000000

# %% [markdown]
# ### 4) Merge all three data

# %%
df_final = pd.merge(numComments, AnsPerQ, on = ['year_month_day', 'community'])
df_final = pd.merge(df_final, ComPerQ, on = ['year_month_day', 'community'])
df_final
# Out:
#       year_month_day  community  comments   AnsPerQ  CommentsPerQ
# 0         2021-09-01          0      2291  1.164056      1.888706
# 1         2021-09-01          1       938  1.032419      2.339152
# 2         2021-09-01          3       841  1.010152      2.134518
# 3         2021-09-01          4      1365  1.141304      3.709239
# 4         2021-09-01          5       569  1.190476      1.505291
# ...              ...        ...       ...       ...           ...
# 10891     2023-08-31         11        22  0.666667      1.222222
# 10892     2023-08-31         13        39  0.413793      1.344828
# 10893     2023-08-31         14         1  0.000000      0.125000
# 10894     2023-08-31         15         2  0.600000      0.400000
# 10895     2023-08-31         17      1222  0.582763      1.671683
#
# [10896 rows x 5 columns]

# %%
df_final_pre4 = pd.read_csv("df_final_pre4.csv")
df_final_pre5 = pd.merge(df_final_pre4, df_final, on = ['year_month_day', 'community'], how = 'left')
df_final_pre5
# Out:
#       year_month_day  T_d  P_t  month  community  techiness   entropy  \
# 0         2021-09-01    0    0      9          0   0.525040  7.298398
# 1         2021-09-01    0    0      9          1   0.412791  7.399966
# 2         2021-09-01    0    0      9          3   0.490224  7.231138
# 3         2021-09-01    0    0      9          4   0.439161  7.709924
# 4         2021-09-01    0    0      9          5   0.461350  7.043218
# ...              ...  ...  ...    ...        ...        ...       ...
# 10707     2023-08-31    1    1      8         11   0.476285  4.175869
# 10708     2023-08-31    1    1      8         13   0.421145  5.528088
# 10709     2023-08-31    1    1      8         14   0.403302  3.344698
# 10710     2023-08-31    1    1      8         15   0.307775  2.947703
# 10711     2023-08-31    1    1      8         17   0.483382  7.779756
#
#        count_q  count_a      ln_q      ln_a  ln_entropy year_month  numUser  \
# 0       1213.0   1029.0  7.100852  6.936343    1.987655    2021-09    22317
# 1        401.0    225.0  5.993961  5.416100    2.001475    2021-09     7820
# 2        394.0    250.0  5.976351  5.521461    1.978396    2021-09     7714
# 3        368.0    305.0  5.908083  5.720312    2.042508    2021-09     7720
# 4        378.0    258.0  5.934894  5.552960    1.952065    2021-09     7509
# ...        ...      ...       ...       ...         ...        ...      ...
# 10707     18.0     12.0  2.890372  2.484907    1.429322    2023-08      343
# 10708     29.0     18.0  3.367296  2.890372    1.709842    2023-08      630
# 10709      8.0      1.0  2.079442  0.000000    1.207377    2023-08      278
# 10710      5.0      4.0  1.609438  1.386294    1.081026    2023-08      122
# 10711    731.0    526.0  6.594413  6.265301    2.051525    2023-08    16051
#
#        ln_numUser  comments   AnsPerQ  CommentsPerQ
# 0       10.013104      2291  1.164056      1.888706
# 1        8.964440       938  1.032419      2.339152
# 2        8.950792       841  1.010152      2.134518
# 3        8.951570      1365  1.141304      3.709239
# 4        8.923858       569  1.190476      1.505291
# ...           ...       ...       ...           ...
# 10707    5.837730        22  0.666667      1.222222
# 10708    6.445720        39  0.413793      1.344828
# 10709    5.627621         1  0.000000      0.125000
# 10710    4.804021         2  0.600000      0.400000
# 10711    9.683526      1222  0.582763      1.671683
#
# [10712 rows x 18 columns]

# %% [markdown]
# ### Check 0s in Comments, AnsPerQ, and CommentsPerQ

# %%
print("Number of 0s in Comments: ", len(df_final_pre5[df_final_pre5['comments'] == 0]))
# Out:
# Number of 0s in Comments:  214

# %%
print("Number of 0s in # Ans per Q: ", len(df_final_pre5[df_final_pre5['AnsPerQ'] == 0]))
# Out:
# Number of 0s in # Ans per Q:  33

# %%
print("Number of 0s in # Comments per Q: ", len(df_final_pre5[df_final_pre5['CommentsPerQ'] == 0]))
# Out:
# Number of 0s in # Comments per Q:  214

# %%
df_final_pre5.groupby('community')['comments'].apply(lambda x: (x != 0).sum()).reset_index()
# Out:
#     community  comments
# 0           0       730
# 1           1       730
# 2           3       730
# 3           4       730
# 4           5       730
# 5           6       730
# 6           7       730
# 7           8       730
# 8           9       730
# 9          10       444
# 10         11       730
# 11         13       730
# 12         14       695
# 13         15       599
# 14         17       730

# %%
df_final_pre5.groupby('community')['AnsPerQ'].apply(lambda x: (x != 0).sum()).reset_index()
# Out:
#     community  AnsPerQ
# 0           0      730
# 1           1      730
# 2           3      730
# 3           4      730
# 4           5      730
# 5           6      730
# 6           7      730
# 7           8      730
# 8           9      730
# 9          10      534
# 10         11      730
# 11         13      730
# 12         14      727
# 13         15      658
# 14         17      730

# %%
df_final_pre5.groupby('community')['CommentsPerQ'].apply(lambda x: (x != 0).sum()).reset_index()
# Out:
#     community  CommentsPerQ
# 0           0           730
# 1           1           730
# 2           3           730
# 3           4           730
# 4           5           730
# 5           6           730
# 6           7           730
# 7           8           730
# 8           9           730
# 9          10           444
# 10         11           730
# 11         13           730
# 12         14           695
# 13         15           599
# 14         17           730

# %%
# Remove rows with 0 value (10,712->10,474)
df_final_pre5 = df_final_pre5[(df_final_pre5['comments'] != 0)&(df_final_pre5['AnsPerQ'] != 0)&(df_final_pre5['CommentsPerQ'] != 0)]
df_final_pre5
# Out:
#       year_month_day  T_d  P_t  month  community  techiness   entropy  \
# 0         2021-09-01    0    0      9          0   0.525040  7.298398
# 1         2021-09-01    0    0      9          1   0.412791  7.399966
# 2         2021-09-01    0    0      9          3   0.490224  7.231138
# 3         2021-09-01    0    0      9          4   0.439161  7.709924
# 4         2021-09-01    0    0      9          5   0.461350  7.043218
# ...              ...  ...  ...    ...        ...        ...       ...
# 10705     2023-08-31    1    1      8          9   0.541652  4.639900
# 10707     2023-08-31    1    1      8         11   0.476285  4.175869
# 10708     2023-08-31    1    1      8         13   0.421145  5.528088
# 10710     2023-08-31    1    1      8         15   0.307775  2.947703
# 10711     2023-08-31    1    1      8         17   0.483382  7.779756
#
#        count_q  count_a      ln_q      ln_a  ln_entropy year_month  numUser  \
# 0       1213.0   1029.0  7.100852  6.936343    1.987655    2021-09    22317
# 1        401.0    225.0  5.993961  5.416100    2.001475    2021-09     7820
# 2        394.0    250.0  5.976351  5.521461    1.978396    2021-09     7714
# 3        368.0    305.0  5.908083  5.720312    2.042508    2021-09     7720
# 4        378.0    258.0  5.934894  5.552960    1.952065    2021-09     7509
# ...        ...      ...       ...       ...         ...        ...      ...
# 10705     31.0     16.0  3.433987  2.772589    1.534693    2023-08      510
# 10707     18.0     12.0  2.890372  2.484907    1.429322    2023-08      343
# 10708     29.0     18.0  3.367296  2.890372    1.709842    2023-08      630
# 10710      5.0      4.0  1.609438  1.386294    1.081026    2023-08      122
# 10711    731.0    526.0  6.594413  6.265301    2.051525    2023-08    16051
#
#        ln_numUser  comments   AnsPerQ  CommentsPerQ
# 0       10.013104      2291  1.164056      1.888706
# 1        8.964440       938  1.032419      2.339152
# 2        8.950792       841  1.010152      2.134518
# 3        8.951570      1365  1.141304      3.709239
# 4        8.923858       569  1.190476      1.505291
# ...           ...       ...       ...           ...
# 10705    6.234411        47  0.612903      1.516129
# 10707    5.837730        22  0.666667      1.222222
# 10708    6.445720        39  0.413793      1.344828
# 10710    4.804021         2  0.600000      0.400000
# 10711    9.683526      1222  0.582763      1.671683
#
# [10474 rows x 18 columns]

# %%
df_final_pre5['ln_comments'] = np.log(df_final_pre5['comments'])
df_final_pre5['ln_AnsPerQ'] = np.log(df_final_pre5['AnsPerQ'])
df_final_pre5['ln_CommentsPerQ'] = np.log(df_final_pre5['CommentsPerQ'])
df_final_pre5
# Out:
# /tmp/ipykernel_1198291/3088801913.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_pre5['ln_comments'] = np.log(df_final_pre5['comments'])
# /tmp/ipykernel_1198291/3088801913.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_pre5['ln_AnsPerQ'] = np.log(df_final_pre5['AnsPerQ'])
# /tmp/ipykernel_1198291/3088801913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_pre5['ln_CommentsPerQ'] = np.log(df_final_pre5['CommentsPerQ'])
#       year_month_day  T_d  P_t  month  community  techiness   entropy  \
# 0         2021-09-01    0    0      9          0   0.525040  7.298398
# 1         2021-09-01    0    0      9          1   0.412791  7.399966
# 2         2021-09-01    0    0      9          3   0.490224  7.231138
# 3         2021-09-01    0    0      9          4   0.439161  7.709924
# 4         2021-09-01    0    0      9          5   0.461350  7.043218
# ...              ...  ...  ...    ...        ...        ...       ...
# 10705     2023-08-31    1    1      8          9   0.541652  4.639900
# 10707     2023-08-31    1    1      8         11   0.476285  4.175869
# 10708     2023-08-31    1    1      8         13   0.421145  5.528088
# 10710     2023-08-31    1    1      8         15   0.307775  2.947703
# 10711     2023-08-31    1    1      8         17   0.483382  7.779756
#
#        count_q  count_a      ln_q  ...  ln_entropy  year_month numUser  \
# 0       1213.0   1029.0  7.100852  ...    1.987655     2021-09   22317
# 1        401.0    225.0  5.993961  ...    2.001475     2021-09    7820
# 2        394.0    250.0  5.976351  ...    1.978396     2021-09    7714
# 3        368.0    305.0  5.908083  ...    2.042508     2021-09    7720
# 4        378.0    258.0  5.934894  ...    1.952065     2021-09    7509
# ...        ...      ...       ...  ...         ...         ...     ...
# 10705     31.0     16.0  3.433987  ...    1.534693     2023-08     510
# 10707     18.0     12.0  2.890372  ...    1.429322     2023-08     343
# 10708     29.0     18.0  3.367296  ...    1.709842     2023-08     630
# 10710      5.0      4.0  1.609438  ...    1.081026     2023-08     122
# 10711    731.0    526.0  6.594413  ...    2.051525     2023-08   16051
#
#        ln_numUser  comments   AnsPerQ  CommentsPerQ  ln_comments  ln_AnsPerQ  \
# 0       10.013104      2291  1.164056      1.888706     7.736744    0.151911
# 1        8.964440       938  1.032419      2.339152     6.843750    0.031905
# 2        8.950792       841  1.010152      2.134518     6.734592    0.010101
# 3        8.951570      1365  1.141304      3.709239     7.218910    0.132172
# 4        8.923858       569  1.190476      1.505291     6.343880    0.174353
# ...           ...       ...       ...           ...          ...         ...
# 10705    6.234411        47  0.612903      1.516129     3.850148   -0.489548
# 10707    5.837730        22  0.666667      1.222222     3.091042   -0.405465
# 10708    6.445720        39  0.413793      1.344828     3.663562   -0.882389
# 10710    4.804021         2  0.600000      0.400000     0.693147   -0.510826
# 10711    9.683526      1222  0.582763      1.671683     7.108244   -0.539974
#
#        ln_CommentsPerQ
# 0             0.635892
# 1             0.849789
# 2             0.758241
# 3             1.310827
# 4             0.408986
# ...                ...
# 10705         0.416160
# 10707         0.200671
# 10708         0.296266
# 10710        -0.916291
# 10711         0.513831
#
# [10474 rows x 21 columns]

# %%
df_final_pre5[['ln_comments', 'ln_AnsPerQ', 'ln_CommentsPerQ']].describe()
# Out:
#         ln_comments    ln_AnsPerQ  ln_CommentsPerQ
# count  10474.000000  10474.000000     10474.000000
# mean       4.964032     -0.127464         0.399770
# std        2.007829      0.254953         0.547408
# min        0.000000     -2.197225        -2.890372
# 25%        3.433987     -0.276538         0.233452
# 50%        5.631212     -0.085910         0.510826
# 75%        6.647364      0.051293         0.716883
# max        7.824846      1.386294         2.197225

# %%
# Save Data
df_final_pre5.to_csv('df_final_pre5.csv', index=False)
