# %% [markdown]
# # Similarity Measure using LSM (Arqade)

# %%
# Import Modules
import pandas as pd
import numpy as np
import sqlite3
import pickle
import os
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm
# Import Dataset
conn = sqlite3.connect('/data1/StackOverflow/_Robustness/Arqade/stack.db')
query = '''
SELECT creation_date, owner_user_id, body
FROM answers
WHERE creation_date >= '2021-09-01';
'''
df = pd.read_sql_query(query, conn)
conn.close()

# %%
df
# Out:
#                 creation_date  owner_user_id  \
# 0     2021-09-01 01:14:47.137       279000.0
# 1     2021-09-01 02:22:40.793        73976.0
# 2     2021-09-01 08:47:21.220       271559.0
# 3     2021-09-01 09:22:21.270        35555.0
# 4     2021-09-01 11:28:17.450         9440.0
# ...                       ...            ...
# 6276  2024-03-31 13:55:07.743       245340.0
# 6277  2024-03-31 15:59:13.490       245340.0
# 6278  2024-03-31 16:04:54.423       108916.0
# 6279  2024-03-31 18:27:47.853       181240.0
# 6280  2024-03-31 21:54:08.783        22577.0
#
#                                                    body
# 0     <p>The punisher In Jiaming's answer is nice, b...
# 1     <p>So I misunderstood the capabilities of the ...
# 2     <p>Unfortunately you can not import ANY assets...
# 3     <p>Steam natively allows choosing where to ins...
# 4     <p>It looks like somehow you switched off Smoo...
# ...                                                 ...
# 6276  <p>How to solve this is very similar to the an...
# 6277  <h2>Outline</h2>\n<p>I have not used cheats, b...
# 6278  <p>The default &quot;Maximum Number of Dropped...
# 6279  <p><a href="https://www.pikminwiki.com/Onion#W...
# 6280  <p>If the monitor has a higher resolution than...
#
# [6281 rows x 3 columns]

# %%
# erase NAs
df_tags = df.dropna(subset=['owner_user_id'])
# Convert types
df_tags['owner_user_id'] = df_tags['owner_user_id'].astype(int).astype(str)
df_tags['creation_date'] = pd.to_datetime(df_tags['creation_date'])
# add year_month variable
df_tags['year_month'] = df_tags['creation_date'].dt.to_period('M')

# Get the total number of unique months
total_months = df_tags['year_month'].nunique()
# Count the number of unique months for each user
user_month_counts = df_tags.groupby('owner_user_id')['year_month'].nunique()
# Filter users who have written posts in every single month
users_in_every_month = user_month_counts[user_month_counts == total_months].index.tolist()

# Filtered data
df_filtered = df_tags[df_tags['owner_user_id'].isin(users_in_every_month)]
# Out:
# /tmp/ipykernel_2778249/1188697006.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tags['owner_user_id'] = df_tags['owner_user_id'].astype(int).astype(str)
# /tmp/ipykernel_2778249/1188697006.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tags['creation_date'] = pd.to_datetime(df_tags['creation_date'])
# /tmp/ipykernel_2778249/1188697006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tags['year_month'] = df_tags['creation_date'].dt.to_period('M')

# %%
df_filtered
# Out:
#                creation_date owner_user_id  \
# 13   2021-09-01 20:54:10.763         87579
# 14   2021-09-01 21:58:20.287         87579
# 16   2021-09-02 00:59:25.427         87579
# 19   2021-09-02 12:25:03.123         87579
# 31   2021-09-03 16:24:52.073         87579
# ...                      ...           ...
# 6177 2024-03-06 13:06:47.573         87579
# 6180 2024-03-06 20:55:12.110         87579
# 6199 2024-03-10 22:11:34.730         87579
# 6200 2024-03-11 09:55:27.047         87579
# 6232 2024-03-17 18:26:07.167         87579
#
#                                                    body year_month
# 13    <p>According to <a href="https://kirby.fandom....    2021-09
# 14    <p>If that &quot;shrinking jar&quot; is the on...    2021-09
# 16    <p>They're DLC items. Maybe you've got them as...    2021-09
# 19    <p>Here's a video tutorial, starting from 8.05...    2021-09
# 31    <p>According to the <a href="https://steamcomm...    2021-09
# ...                                                 ...        ...
# 6177  <p>It's like a threshold, you need to fill the...    2024-03
# 6180  <p>Not an actual answer, but I found a solutio...    2024-03
# 6199  <p>You just need a command block under the pre...    2024-03
# 6200  <p>These are the games I can recognize (with Y...    2024-03
# 6232  <p>This happened to me when I had to leave Lyd...    2024-03
#
# [403 rows x 4 columns]

# %%
df_grouped = df_filtered.groupby(['owner_user_id','year_month'])['body'].agg(lambda x: '\n'.join(x)).reset_index()

# %%
df_grouped
# Out:
#    owner_user_id year_month                                               body
# 0          87579    2021-09  <p>According to <a href="https://kirby.fandom....
# 1          87579    2021-10  <p>According to <a href="https://www.ign.com/w...
# 2          87579    2021-11  <p>Apparently, it has nothing to do with quest...
# 3          87579    2021-12  <p>The <a href="https://en.wikipedia.org/wiki/...
# 4          87579    2022-01  <p>It's <a href="https://play.google.com/store...
# 5          87579    2022-02  <p>They do stay loaded. But unfortunately farm...
# 6          87579    2022-03  <p>You need to consider that each quick move g...
# 7          87579    2022-04  <p>This worked for me, of course next move is ...
# 8          87579    2022-05  <p>Charizard's standard ability is Blaze, whil...
# 9          87579    2022-06  <p>There's no need to figure out a complicated...
# 10         87579    2022-07  <p>The <code>@s</code> target selector is used...
# 11         87579    2022-08  <p>If you try to get the game from the store, ...
# 12         87579    2022-09  <p>My speculation comes from <a href="https://...
# 13         87579    2022-10  <p>You perform a timed landing when, after a j...
# 14         87579    2022-11  <p>According to <a href="https://minecraft.wik...
# 15         87579    2022-12  <p>Yes, you need a PSN account to purchase con...
# 16         87579    2023-01  <p>According to <a href="https://sonic.fandom....
# 17         87579    2023-02  <p>As you correctly wrote, shininess is immuta...
# 18         87579    2023-03  <p>Looking at the yellow area, the middle 2 sa...
# 19         87579    2023-04  <p>According to <a href="https://www.reddit.co...
# 20         87579    2023-05  <p>Yes, they do.</p>\n<p>According to <a href=...
# 21         87579    2023-06  <p>I deleted all my sets, creating a new one w...
# 22         87579    2023-07  <p>As already said in the other answer, the ma...
# 23         87579    2023-08  <p>Fill command has this syntax:</p>\n<pre><co...
# 24         87579    2023-09  <p>Apparently there's no current way to unlike...
# 25         87579    2023-10  <p>Typically digital/physical saves are the sa...
# 26         87579    2023-11  <p>If you mean that you want to transfer saved...
# 27         87579    2023-12  <p>We need a couple of numbers:</p>\n<ul>\n<li...
# 28         87579    2024-01  <p>My guess will be <a href="https://en.wikipe...
# 29         87579    2024-02  <p>It appears that normal players will receive...
# 30         87579    2024-03  <p>It's like a threshold, you need to fill the...

# %%
year_month = list(df_grouped['year_month'].unique().astype('str')) # get unique year_month

# %%
year_month
# Out:
# ['2021-09',
#  '2021-10',
#  '2021-11',
#  '2021-12',
#  '2022-01',
#  '2022-02',
#  '2022-03',
#  '2022-04',
#  '2022-05',
#  '2022-06',
#  '2022-07',
#  '2022-08',
#  '2022-09',
#  '2022-10',
#  '2022-11',
#  '2022-12',
#  '2023-01',
#  '2023-02',
#  '2023-03',
#  '2023-04',
#  '2023-05',
#  '2023-06',
#  '2023-07',
#  '2023-08',
#  '2023-09',
#  '2023-10',
#  '2023-11',
#  '2023-12',
#  '2024-01',
#  '2024-02',
#  '2024-03']
