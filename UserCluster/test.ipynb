# %%
# df_analysis
import pickle
with open(f'df_analysis_final.pickle', 'rb') as fw:
    data = pickle.load(fw)

# %%
data[data['community'] == 14]
# Out:
#      owner_user_id year_month  \
# 5304       1693192    2021-09
# 5305       1693192    2021-10
# 5306       1693192    2021-11
# 5307       1693192    2021-12
# 5308       1693192    2022-01
# 5309       1693192    2022-02
# 5310       1693192    2022-03
# 5311       1693192    2022-04
# 5312       1693192    2022-05
# 5313       1693192    2022-06
# 5314       1693192    2022-07
# 5315       1693192    2022-08
# 5316       1693192    2022-09
# 5317       1693192    2022-10
# 5318       1693192    2022-11
# 5319       1693192    2022-12
# 5320       1693192    2023-01
# 5321       1693192    2023-02
# 5322       1693192    2023-03
# 5323       1693192    2023-04
# 5324       1693192    2023-05
# 5325       1693192    2023-06
# 5326       1693192    2023-07
# 5327       1693192    2023-08
# 9480        315168    2021-09
# 9481        315168    2021-10
# 9482        315168    2021-11
# 9483        315168    2021-12
# 9484        315168    2022-01
# 9485        315168    2022-02
# 9486        315168    2022-03
# 9487        315168    2022-04
# 9488        315168    2022-05
# 9489        315168    2022-06
# 9490        315168    2022-07
# 9491        315168    2022-08
# 9492        315168    2022-09
# 9493        315168    2022-10
# 9494        315168    2022-11
# 9495        315168    2022-12
# 9496        315168    2023-01
# 9497        315168    2023-02
# 9498        315168    2023-03
# 9499        315168    2023-04
# 9500        315168    2023-05
# 9501        315168    2023-06
# 9502        315168    2023-07
# 9503        315168    2023-08
#
#                                                    body  community
# 5304  <p>It depends on your <code>genesis.json</code...         14
# 5305  <p>In the second snippet, you're trying to set...         14
# 5306  <p>The <code>txlist</code> endpoint (<a href="...         14
# 5307  <blockquote>\n<p><em>Warning: SPDX license ide...         14
# 5308  <p>The low-level native <code>call()</code> is...         14
# 5309  <p>You can <strong>read</strong> storage prope...         14
# 5310  <p>This seems to be a bug in the compiler.</p>...         14
# 5311  <p>Cannnot use the <code>new</code> keyword fo...         14
# 5312  <p>Your snippet is trying to assign into 0th i...         14
# 5313  <p>You can validate against <code>window.ether...         14
# 5314  <blockquote>\n<p><em>the value passed into the...         14
# 5315  <p>Web3js is &quot;just&quot; a wrapper for RP...         14
# 5316  <p>ERC-20 doesn't have any standardized way to...         14
# 5317  <p>Contract and interface type acts as a point...         14
# 5318  <p>Assuming you're using the Hardhat Chai Matc...         14
# 5319  <p>You can create mutliple web3js instances - ...         14
# 5320  <p>Blockscan UI accepts tupple items wrapped i...         14
# 5321  <p>Assuming that the contract is deployed on a...         14
# 5322  <p>When a contract performs an external call t...         14
# 5323  <p>MetaMask shows the human readable format be...         14
# 5324  <p>The <a href="https://goerli.etherscan.io/ad...         14
# 5325  <p>The list of internal transactions on Ethers...         14
# 5326  <p>Can't do that directly. There are several w...         14
# 5327  <p>It can pull all of your tokens that you hav...         14
# 9480  <blockquote>\n<p>if the block contains the tra...         14
# 9481  <p>At the moment, every dApp should provide it...         14
# 9482  <p>Solidity does not offer built-in math funct...         14
# 9483  <blockquote>\n<p>Is it possible to authorize a...         14
# 9484  <p>This is a good question, but unfortunately,...         14
# 9485  <p>To get funds on the account, you transfer t...         14
# 9486  <p>Uniswap version 1 uses library contracts wi...         14
# 9487  <blockquote>\n<p>My challenge is how can I aut...         14
# 9488  <p>Solidity mapping does not support iteration...         14
# 9489  <blockquote>\n<p>Is it a bad practice?</p>\n</...         14
# 9490  <blockquote>\n<p>Why shouldn't I just deploy t...         14
# 9491  <p>I am not sure if there is Sphinx support fo...         14
# 9492  <p>You can <a href="https://packaging.python.o...         14
# 9493  <blockquote>\n<p>but how can I call Metamask f...         14
# 9494  <blockquote>\n<p>get a list of addresses of th...         14
# 9495  <p>As per LazyOne's suggetion you can see some...         14
# 9496  <p>The screenshot is missing, so I cannot comm...         14
# 9497  <p>You are doing it correctly. Make sure you h...         14
# 9498  <p>To make a transaction human readable you ne...         14
# 9499  <p>Likely you need to do <code>pip install -e<...         14
# 9500  <p>It is possible to interact with <a href="ht...         14
# 9501  <blockquote>\n<p>I am trying to perform multip...         14
# 9502  <p>You can simulate a transaction by</p>\n<ul>...         14
# 9503  <p>I was facing the same issue with Homebrew, ...         14

# %%
with open(file = '/data1/StackOverflow/_Robustness/TagCluster/louvain_community_pre.pickle', mode = 'rb') as file:
    df_clusters = pickle.load(file)

# %%
df_clusters[df_clusters['community'] == 9]
# Out:
#                          tag  community  tag_count
# 45                    django          9      44012
# 46       djangorestframework          9       7732
# 453              djangoforms          9       2955
# 489             djangomodels          9       8034
# 490                djangoorm          9        777
# ...                      ...        ...        ...
# 42623         libmysqlclient          9         20
# 42714          djangocookies          9          9
# 42757  djangoadvancedfilters          9          3
# 42874                yuglify          9          1
# 42897             djangoquiz          9          2
#
# [374 rows x 3 columns]
